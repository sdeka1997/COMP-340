# %% [markdown]
# ## Continuation of Lab 3 to complete review extraction

# %% [markdown]
# ## Parameterization and Pagination
#
# And before we can get any reviews on restaurants, we need to actually get the metadata on ALL of the restaurants in Pittsburgh. Notice above that while Yelp told us that there are ~14900, the response contained far fewer actual `Business` objects. This is due to pagination and is a safeguard against returning __TOO__ much data in a single request (what would happen if there were 100,000 restaurants?) and can be used in conjuction with _rate limiting_ as well as a way to throttle and protect access to Yelp data.
#
# > If an API has 1,000,000 records, but only returns 10 records per page and limits you to 5 requests per second... how long will it take to acquire ALL of the records contained in the API?
#
# One of the ways that APIs are an improvement over plain web scraping is the ability to make __parameterized__ requests. Just like the Python functions you have been writing have arguments (or parameters) that allow you to customize its behavior/actions (an output) without having to rewrite the function entirely, we can parameterize the queries we make to the Yelp API to filter the results it returns.

# %% [markdown]
# ## Aquire all of the restaurants in Houston (on Yelp)
#
# Again using the [API documentation](https://www.yelp.com/developers/documentation/v3/business_search) for the `search` endpoint, fill in the following function to retrieve all of the _Restuarants_ (using categories) for a given query. Again you should use your `read_api_key()` function outside of the `all_restaurants()` stub to read the API Key used for the requests. You will need to account for __pagination__ and __[rate limiting](https://www.yelp.com/developers/faq)__ to:
#
# 1. Retrieve all of the Business objects (# of business objects should equal `total` in the response). Paginate by querying 20 restaurants each request.
# 2. Pause slightly (at least 200 milliseconds) between subsequent requests so as to not overwhelm the API (and get blocked).
#
# As always with API access, make sure you follow all of the [API's policies](https://www.yelp.com/developers/api_terms) and use the API responsibly and respectfully.
#
# ** DO NOT MAKE TOO MANY REQUESTS TOO QUICKLY OR YOUR KEY MAY BE BLOCKED **
#
# > Again, you can test your function with an individual neighborhod in Houston (I recommend Rice Village). Houston has a lot of restaurants... meaning it will take a lot of time to download them all.
#
# Hint:
# - time.sleep(n) is the function that will implement the pause between calls to yelp_search

# %%
import requests
def read_api_key(file):
    f = open(file,'r')
    api_key = f.read().replace('\n','')
    f.close()
    return api_key

api_key = read_api_key('api_key.txt')


import json
def yelp_search(api_key, query, location,offset=0):
    """
    Make an authenticated request to the Yelp API.

    Args:
        query (string): Search term

    Returns:
        total (integer): total number of businesses on Yelp corresponding to the query
        businesses (list): list of dicts representing each business
    """
    url = "https://api.yelp.com/v3/businesses/search"
    headers = {"Authorization": "Bearer %s" % api_key}
    url_params = {
        'term': query.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'offset':offset
    }
    response = requests.request('GET', url, headers=headers, params=url_params)
    data = json.loads(response.content)
    num = data['total']
    objects = data['businesses']
    
    return (num, objects)


import time
def all_restaurants(api_key, query, location):
    """
    Retrieve ALL the restaurants on Yelp for a given query.

    Args:
        query (string): Search term

    Returns:
        results (list): list of dicts representing each business
    """
    
    # Write solution here (about 10-12 lines)
    all_rest = []
    n=0
    num = float('Inf')
    while n < num:
        (num, objects) = yelp_search(api_key, query, location,offset=n)
        for dictionary in objects:
            all_rest.append(dictionary)
        n += 20    
    time.sleep(0.200) 
    return all_rest

# %% [markdown]
# ## Test all_restaurants function

# %%
data = all_restaurants(api_key, 'Indian','Houston, TX')

# %% [markdown]
# Now that we have the metadata on all of the restaurants in Houston (or at least the ones listed on Yelp), we can retrieve the reviews and ratings. The Yelp API gives us aggregate information on ratings but it doesn't give us the review text or individual users' ratings for a restaurant. For that we need to turn to web scraping, but to find out what pages to scrape we first need to parse our JSON from the API to extract the URLs of the restaurants.
#
# In general, it is a best practice to seperate the act of __downloading__ data and __parsing__ data. This ensures that your data processing pipeline is modular and extensible (and autogradable ;). This decoupling also solves the problem of expensive downloading but cheap parsing (in terms of computation and time).

# %% [markdown]
# ## Parse the API Responses and Extract the URLs
#
# Because we want to seperate the __downloading__ from the __parsing__, fill in the following function to parse the URLs pointing to the restaurants on `yelp.com`. As input your function should expect a string of [properly formatted JSON](http://www.json.org/) (which is similar to __BUT__ not the same as a Python dictionary) and as output should return a Python list of strings. The input JSON will be structured as follows (extracted from the [sample](https://www.yelp.com/developers/documentation/v3/business_search) on the Yelp API page):
#
# ```json
#  [
#     {
#       "rating": 4,
#       "price": "$",
#       "phone": "+14152520800",
#       "id": "four-barrel-coffee-san-francisco",
#       "is_closed": false,
#       "categories": [
#         {
#           "alias": "coffee",
#           "title": "Coffee & Tea"
#         }
#       ],
#       "review_count": 1738,
#       "name": "Four Barrel Coffee",
#       "url": "https://www.yelp.com/biz/four-barrel-coffee-san-francisco",
#       "coordinates": {
#         "latitude": 37.7670169511878,
#         "longitude": -122.42184275
#       },
#       "image_url": "http://s3-media2.fl.yelpcdn.com/bphoto/MmgtASP3l_t4tPCL1iAsCg/o.jpg",
#       "location": {
#         "city": "San Francisco",
#         "country": "US",
#         "address2": "",
#         "address3": "",
#         "state": "CA",
#         "address1": "375 Valencia St",
#         "zip_code": "94103"
#       },
#       "distance": 1604.23,
#       "transactions": ["pickup", "delivery"]
#     }
#   ]
# ```

# %%
import pandas
def parse_api_response(data):
    """
    Parse Yelp API results to extract restaurant URLs.
    
    Args:
        data (string): String of properly formatted JSON.

    Returns:
        Pandas dataframe with name, rating, price, review_count and URL in the input data
    """
    # Write solution here (about 12 lines of code)
    
    new_dict = {}
    new_list = []
    counter = 0
    for obj in data:
        new_dict[counter] = [
            obj['name'],
            obj['rating'],
            obj.get('price','n/a'),
            obj['review_count'],
            obj['url']
        ]
        counter += 1
    return pandas.DataFrame.from_dict(new_dict, orient='index').rename(index=str, columns={0: "name", 1: "rating", 2: "price", 3: "review_count", 4: "url"}).set_index('name')

# %% [markdown]
# ## Test parse_api_response function

# %%
df= parse_api_response(data)
df
# Out:
#                                   rating price  review_count  \
# name
# Surya India                          4.0    $$           196
# Tarka Indian Kitchen                 4.0     $           350
# Govinda's Vegetarian Cuisine         4.5    $$           244
# Desi Kitchen                         4.5    $$            19
# Indika                               4.0   $$$           408
# Sai Bhog                             4.5   n/a            22
# India's Restaurant                   3.5    $$           377
# Cowboys & Indians Tex-In Kitchen     4.0    $$           221
# Pondicheri                           3.5    $$           940
# Mayuri Express                       4.0    $$            36
# Maharaja Bhog                        4.0    $$           500
# Kiran's                              4.0   $$$           127
# Sangam Chettinad Indian Cuisine      4.0    $$            52
# Shiva Indian Restaurant              3.5    $$           416
# Deli Deluxe                          4.5     $            64
# Bombay Pizza                         4.0    $$          1008
# Khyber North Indian Grill            4.0    $$           262
# Tandoori Hut                         4.0    $$            83
# Nirvana Indian Restaurant            4.0    $$           215
# Shri Balaji Bhavan                   4.0     $           278
# Flying Idlis                         4.5     $           133
# Aga's Restaurant & Catering          4.5    $$           526
# Cafe India                           4.0    $$           153
# Taste of Chennai                     4.5    $$            37
# Narin's Bombay Brasserie             3.5    $$           257
# Yaal Tiffins                         4.0    $$           149
# Biryani Factory                      4.5    $$            93
# Tru India                            4.0    $$            35
# Amar Indian-European Cuisine         4.5    $$            92
# The Curry House                      4.5    $$           335
# ...                                  ...   ...           ...
# Hungry's- Rice Village               3.5    $$           574
# D'Caribbean Curry Spot               4.5    $$           242
# Masala Wok                           3.0    $$            95
# Field of Greens                      3.5    $$           250
# Swagruha Curry Point                 2.5   n/a             3
# Goode Company Barbeque               3.5    $$          1042
# Kabob Korner                         4.0    $$           248
# Bombay Palace                        3.5    $$            64
# Sugar Land Grocer & Halal Meat       3.5     $            18
# New India Supermarket                3.0    $$             8
# Heritage India                       2.5    $$             5
# Bollywood Chowpaty Chaat             2.5     $            47
# Mumbai Grill                         2.5     $            14
# Cafe Yasmeen                         3.5    $$            56
# Nizam's Restaurant                   2.5    $$             4
# Standard Sweets                      2.5    $$            11
# Tempura Grill                        3.0    $$            47
# Kabobish Cafe & Grill                4.0   n/a            13
# Top It Pizza                         4.5     $           351
# Alsafa                               3.5     $            38
# P.F. Chang's                         3.0    $$           156
# Sara's Halal Burgers & Grill         4.0     $           100
# Apna Bazaar                          4.5    $$             4
# Agha juice And Cafe                  3.5     $            52
# Ashar's Kitchen                      3.0    $$            72
# OMG! Burger                          3.5    $$           193
# Chaat House                          1.0   n/a             1
# New Food Gallery                     4.0     $            43
# Louisana Famous Fried Chicken        2.5   n/a            23
# Golden Corral                        2.0    $$            93
#
#                                                                                 url
# name
# Surya India                       https://www.yelp.com/biz/surya-india-houston?a...
# Tarka Indian Kitchen              https://www.yelp.com/biz/tarka-indian-kitchen-...
# Govinda's Vegetarian Cuisine      https://www.yelp.com/biz/govindas-vegetarian-c...
# Desi Kitchen                      https://www.yelp.com/biz/desi-kitchen-houston-...
# Indika                            https://www.yelp.com/biz/indika-houston?adjust...
# Sai Bhog                          https://www.yelp.com/biz/sai-bhog-houston?adju...
# India's Restaurant                https://www.yelp.com/biz/indias-restaurant-hou...
# Cowboys & Indians Tex-In Kitchen  https://www.yelp.com/biz/cowboys-and-indians-t...
# Pondicheri                        https://www.yelp.com/biz/pondicheri-houston?ad...
# Mayuri Express                    https://www.yelp.com/biz/mayuri-express-housto...
# Maharaja Bhog                     https://www.yelp.com/biz/maharaja-bhog-houston...
# Kiran's                           https://www.yelp.com/biz/kirans-houston-4?adju...
# Sangam Chettinad Indian Cuisine   https://www.yelp.com/biz/sangam-chettinad-indi...
# Shiva Indian Restaurant           https://www.yelp.com/biz/shiva-indian-restaura...
# Deli Deluxe                       https://www.yelp.com/biz/deli-deluxe-houston-2...
# Bombay Pizza                      https://www.yelp.com/biz/bombay-pizza-houston?...
# Khyber North Indian Grill         https://www.yelp.com/biz/khyber-north-indian-g...
# Tandoori Hut                      https://www.yelp.com/biz/tandoori-hut-houston?...
# Nirvana Indian Restaurant         https://www.yelp.com/biz/nirvana-indian-restau...
# Shri Balaji Bhavan                https://www.yelp.com/biz/shri-balaji-bhavan-ho...
# Flying Idlis                      https://www.yelp.com/biz/flying-idlis-houston-...
# Aga's Restaurant & Catering       https://www.yelp.com/biz/agas-restaurant-and-c...
# Cafe India                        https://www.yelp.com/biz/cafe-india-houston-6?...
# Taste of Chennai                  https://www.yelp.com/biz/taste-of-chennai-hous...
# Narin's Bombay Brasserie          https://www.yelp.com/biz/narins-bombay-brasser...
# Yaal Tiffins                      https://www.yelp.com/biz/yaal-tiffins-houston?...
# Biryani Factory                   https://www.yelp.com/biz/biryani-factory-houst...
# Tru India                         https://www.yelp.com/biz/tru-india-houston?adj...
# Amar Indian-European Cuisine      https://www.yelp.com/biz/amar-indian-european-...
# The Curry House                   https://www.yelp.com/biz/the-curry-house-humbl...
# ...                                                                             ...
# Hungry's- Rice Village            https://www.yelp.com/biz/hungrys-rice-village-...
# D'Caribbean Curry Spot            https://www.yelp.com/biz/d-caribbean-curry-spo...
# Masala Wok                        https://www.yelp.com/biz/masala-wok-sugarland?...
# Field of Greens                   https://www.yelp.com/biz/field-of-greens-houst...
# Swagruha Curry Point              https://www.yelp.com/biz/swagruha-curry-point-...
# Goode Company Barbeque            https://www.yelp.com/biz/goode-company-barbequ...
# Kabob Korner                      https://www.yelp.com/biz/kabob-korner-katy?adj...
# Bombay Palace                     https://www.yelp.com/biz/bombay-palace-sugar-l...
# Sugar Land Grocer & Halal Meat    https://www.yelp.com/biz/sugar-land-grocer-and...
# New India Supermarket             https://www.yelp.com/biz/new-india-supermarket...
# Heritage India                    https://www.yelp.com/biz/heritage-india-staffo...
# Bollywood Chowpaty Chaat          https://www.yelp.com/biz/bollywood-chowpaty-ch...
# Mumbai Grill                      https://www.yelp.com/biz/mumbai-grill-sugar-la...
# Cafe Yasmeen                      https://www.yelp.com/biz/cafe-yasmeen-sugar-la...
# Nizam's Restaurant                https://www.yelp.com/biz/nizams-restaurant-mis...
# Standard Sweets                   https://www.yelp.com/biz/standard-sweets-sugar...
# Tempura Grill                     https://www.yelp.com/biz/tempura-grill-sugar-l...
# Kabobish Cafe & Grill             https://www.yelp.com/biz/kabobish-cafe-and-gri...
# Top It Pizza                      https://www.yelp.com/biz/top-it-pizza-houston?...
# Alsafa                            https://www.yelp.com/biz/alsafa-katy?adjust_cr...
# P.F. Chang's                      https://www.yelp.com/biz/p-f-changs-houston-3?...
# Sara's Halal Burgers & Grill      https://www.yelp.com/biz/saras-halal-burgers-a...
# Apna Bazaar                       https://www.yelp.com/biz/apna-bazaar-missouri-...
# Agha juice And Cafe               https://www.yelp.com/biz/agha-juice-and-cafe-s...
# Ashar's Kitchen                   https://www.yelp.com/biz/ashars-kitchen-sugar-...
# OMG! Burger                       https://www.yelp.com/biz/omg-burger-katy-2?adj...
# Chaat House                       https://www.yelp.com/biz/chaat-house-sugar-lan...
# New Food Gallery                  https://www.yelp.com/biz/new-food-gallery-suga...
# Louisana Famous Fried Chicken     https://www.yelp.com/biz/louisana-famous-fried...
# Golden Corral                     https://www.yelp.com/biz/golden-corral-spring?...
#
# [254 rows x 4 columns]

# %% [markdown]
# ## Sort restaurants by rating and price

# %%
# sort df descending in rating, and ascending in price
df.sort_values(['rating', 'price'], ascending=[0, 1])
# Out:
#                                rating price  review_count  \
# name
# Dilpasand Mithai & Snacks         5.0     $             2
# India in a Box                    5.0    $$            22
# Deli Deluxe                       4.5     $            64
# Flying Idlis                      4.5     $           133
# Desi Bun Kabab & Grill Cafe       4.5     $            94
# Khan BBQ & Grill                  4.5     $           108
# Masala Munchies                   4.5     $            23
# Tacos 'N' Frankies                4.5     $            60
# Egg N More                        4.5     $            27
# Doshi House Café                  4.5     $           337
# Bismillah Cafe                    4.5     $           117
# Tastee Pizza                      4.5     $            84
# Desi Kitchen                      4.5     $            15
# Gyro Hut                          4.5     $            37
# Tastee Pizza & Wings              4.5     $            19
# Grand Indian Kitchen              4.5     $            57
# The Gyro Guys                     4.5     $           112
# Indian Express                    4.5     $            67
# Larosh Grill                      4.5     $           153
# Chettinad Indian Cuisine          4.5     $            42
# Chowpatty Express                 4.5     $            74
# Gyro King                         4.5     $           624
# Natura Cafe                       4.5     $            18
# Adam's Halal Meat Market          4.5     $            15
# Busy Boy Sandwiches               4.5     $           126
# Tandoorz Kabob & Grill            4.5     $            96
# Dilpasand Mithai & Snacks         4.5     $            32
# Daily Juice Cafe                  4.5     $            20
# Top It Pizza                      4.5     $           351
# Govinda's Vegetarian Cuisine      4.5    $$           244
# ...                               ...   ...           ...
# Bombay to Beijing                 3.0    $$           117
# Masala Wok                        3.0    $$            95
# New India Supermarket             3.0    $$             8
# Tempura Grill                     3.0    $$            47
# P.F. Chang's                      3.0    $$           156
# Ashar's Kitchen                   3.0    $$            72
# Lazeeza Restaurant                2.5     $            38
# Fresh Food Company                2.5     $            14
# Bollywood Chowpaty Chaat          2.5     $            47
# Mumbai Grill                      2.5     $            14
# Ashka's Dhaba                     2.5    $$             3
# Biryani Bistro                    2.5    $$            23
# Madras Pavillion                  2.5    $$            42
# Heritage India                    2.5    $$             5
# Nizam's Restaurant                2.5    $$             4
# Standard Sweets                   2.5    $$            11
# Tandoori Nite                     2.5   n/a             9
# Swagruha Curry Point              2.5   n/a             3
# Louisana Famous Fried Chicken     2.5   n/a            23
# Lazeeza Restaurant                2.0    $$            39
# Mehfil Grill & Pan Shop           2.0    $$             3
# Saravanaa Bhavan                  2.0    $$            33
# Pakwan House                      2.0    $$            17
# Golden Corral                     2.0    $$            93
# Fire And Ice                      2.0   n/a             2
# Bombay Chowpatty                  2.0   n/a            11
# Eastern Grill Restaurant          2.0   n/a             1
# The Clay Pot                      1.5   n/a             2
# Jai Ho                            1.0    $$             1
# Chaat House                       1.0   n/a             1
#
#                                                                              url
# name
# Dilpasand Mithai & Snacks      https://www.yelp.com/biz/dilpasand-mithai-and-...
# India in a Box                 https://www.yelp.com/biz/india-in-a-box-pearla...
# Deli Deluxe                    https://www.yelp.com/biz/deli-deluxe-houston-2...
# Flying Idlis                   https://www.yelp.com/biz/flying-idlis-houston-...
# Desi Bun Kabab & Grill Cafe    https://www.yelp.com/biz/desi-bun-kabab-and-gr...
# Khan BBQ & Grill               https://www.yelp.com/biz/khan-bbq-and-grill-ho...
# Masala Munchies                https://www.yelp.com/biz/masala-munchies-houst...
# Tacos 'N' Frankies             https://www.yelp.com/biz/tacos-n-frankies-hous...
# Egg N More                     https://www.yelp.com/biz/egg-n-more-houston?ad...
# Doshi House Café               https://www.yelp.com/biz/doshi-house-caf%C3%A9...
# Bismillah Cafe                 https://www.yelp.com/biz/bismillah-cafe-housto...
# Tastee Pizza                   https://www.yelp.com/biz/tastee-pizza-houston-...
# Desi Kitchen                   https://www.yelp.com/biz/desi-kitchen-houston?...
# Gyro Hut                       https://www.yelp.com/biz/gyro-hut-houston-3?ad...
# Tastee Pizza & Wings           https://www.yelp.com/biz/tastee-pizza-and-wing...
# Grand Indian Kitchen           https://www.yelp.com/biz/grand-indian-kitchen-...
# The Gyro Guys                  https://www.yelp.com/biz/the-gyro-guys-houston...
# Indian Express                 https://www.yelp.com/biz/indian-express-sugar-...
# Larosh Grill                   https://www.yelp.com/biz/larosh-grill-katy?adj...
# Chettinad Indian Cuisine       https://www.yelp.com/biz/chettinad-indian-cuis...
# Chowpatty Express              https://www.yelp.com/biz/chowpatty-express-kat...
# Gyro King                      https://www.yelp.com/biz/gyro-king-houston?adj...
# Natura Cafe                    https://www.yelp.com/biz/natura-cafe-houston?a...
# Adam's Halal Meat Market       https://www.yelp.com/biz/adams-halal-meat-mark...
# Busy Boy Sandwiches            https://www.yelp.com/biz/busy-boy-sandwiches-h...
# Tandoorz Kabob & Grill         https://www.yelp.com/biz/tandoorz-kabob-and-gr...
# Dilpasand Mithai & Snacks      https://www.yelp.com/biz/dilpasand-mithai-and-...
# Daily Juice Cafe               https://www.yelp.com/biz/daily-juice-cafe-hous...
# Top It Pizza                   https://www.yelp.com/biz/top-it-pizza-houston?...
# Govinda's Vegetarian Cuisine   https://www.yelp.com/biz/govindas-vegetarian-c...
# ...                                                                          ...
# Bombay to Beijing              https://www.yelp.com/biz/bombay-to-beijing-sug...
# Masala Wok                     https://www.yelp.com/biz/masala-wok-sugarland?...
# New India Supermarket          https://www.yelp.com/biz/new-india-supermarket...
# Tempura Grill                  https://www.yelp.com/biz/tempura-grill-sugar-l...
# P.F. Chang's                   https://www.yelp.com/biz/p-f-changs-houston-3?...
# Ashar's Kitchen                https://www.yelp.com/biz/ashars-kitchen-sugar-...
# Lazeeza Restaurant             https://www.yelp.com/biz/lazeeza-restaurant-ho...
# Fresh Food Company             https://www.yelp.com/biz/fresh-food-company-ho...
# Bollywood Chowpaty Chaat       https://www.yelp.com/biz/bollywood-chowpaty-ch...
# Mumbai Grill                   https://www.yelp.com/biz/mumbai-grill-sugar-la...
# Ashka's Dhaba                  https://www.yelp.com/biz/ashkas-dhaba-houston?...
# Biryani Bistro                 https://www.yelp.com/biz/biryani-bistro-sugar-...
# Madras Pavillion               https://www.yelp.com/biz/madras-pavillion-suga...
# Heritage India                 https://www.yelp.com/biz/heritage-india-staffo...
# Nizam's Restaurant             https://www.yelp.com/biz/nizams-restaurant-mis...
# Standard Sweets                https://www.yelp.com/biz/standard-sweets-sugar...
# Tandoori Nite                  https://www.yelp.com/biz/tandoori-nite-houston...
# Swagruha Curry Point           https://www.yelp.com/biz/swagruha-curry-point-...
# Louisana Famous Fried Chicken  https://www.yelp.com/biz/louisana-famous-fried...
# Lazeeza Restaurant             https://www.yelp.com/biz/lazeeza-restaurant-ho...
# Mehfil Grill & Pan Shop        https://www.yelp.com/biz/mehfil-grill-and-pan-...
# Saravanaa Bhavan               https://www.yelp.com/biz/saravanaa-bhavan-suga...
# Pakwan House                   https://www.yelp.com/biz/pakwan-house-houston?...
# Golden Corral                  https://www.yelp.com/biz/golden-corral-spring?...
# Fire And Ice                   https://www.yelp.com/biz/fire-and-ice-houston?...
# Bombay Chowpatty               https://www.yelp.com/biz/bombay-chowpatty-mead...
# Eastern Grill Restaurant       https://www.yelp.com/biz/eastern-grill-restaur...
# The Clay Pot                   https://www.yelp.com/biz/the-clay-pot-houston?...
# Jai Ho                         https://www.yelp.com/biz/jai-ho-houston-2?adju...
# Chaat House                    https://www.yelp.com/biz/chaat-house-sugar-lan...
#
# [254 rows x 4 columns]

# %% [markdown]
# As we can see, JSON is quite trivial to parse (which is not the case with HTML as we will see in a second) and work with programmatically. This is why it is one of the most ubiquitous data serialization formats (especially for ReSTful APIs) and a huge benefit of working with a well defined API if one exists. But APIs do not always exists or provide the data we might need, and as a last resort we can always scrape web pages...

# %% [markdown]
# # Optional part of the lab

# %% [markdown]
# ## Working with Web Pages (and HTML)
#
# Think of APIs as similar to accessing a application's database itself (something you can interactively query and receive structured data back). But the results are usually in a somewhat raw form with no formatting or visual representation (like the results from a database query). This is a benefit _AND_ a drawback depending on the end use case. For data science and _programatic_ analysis this raw form is quite ideal, but for an end user requesting information from a _graphical interface_ (like a web browser) this is very far from ideal since it takes some cognitive overhead to interpret the raw information. And vice versa, if we have HTML it is quite easy for a human to visually interpret it, but to try to perform some type of programmatic analysis we first need to parse the HTML into a more structured form.
#
# > As a general rule of thumb, if the data you need can be accessed or retrieved in a structured form (either from a bulk download or API) prefer that first. But if the data you want (and need) is not as in our case we need to resort to alternative (messier) means.
#
# Going back to the "hello world" example of question 1 with the NYT, we will do something similar to retrieve the HTML of the Yelp site itself (rather than going through the API) programmatically as text.

# %% [markdown]
# ## Extract reviews of from a Yelp restaurant Page
#
# Using `BeautifulSoup`, parse the HTML of a Yelp restaurant page to extract information about the restaurant as well as all the reviews in a structured form. This requires you to follow the URL to the next page of reviews until there are no more pages. Fill in following function stub to parse a restaurant page  and return a dictionary:
# * information: name, address, telephone, cuisine, aggregate rating
# * the reviews as a structured Python dictionary
#
#
# For each review be sure to structure your Python dictionary as follows. The order of the keys doesn't matter, only the keys and the data type of the values:
#
# ```python
# {
#     'review_id': str
#     'user_id': str
#     'rating': float
#     'date': str ('yyyy-mm-dd')
#     'text': str
# }
#
# # Example
# {
#     'review_id': '12345'
#     'user_id': '6789'
#     'rating': 4.7
#     'date': '2016-01-23'
#     'text': "Wonderful!"
# }
# ```
#
# > There can be issues with Beautiful Soup using various parsers, for maximum compatibility (and fewest errors) initialize the library with the default (and Python standard library parser): `BeautifulSoup(markup, "html.parser")`

# %%
def extract_reviews(url):
    """
    Parse the reviews of a restaurant.
    
    Args:
        url (string): url corresponding to a Yelp restaurant

    Returns:
        dictionary:
            keys 1:5: name, address, telephone, aggregate rating, cuisine
            key 6: list of dictionaries corresponding to the extracted review information
            
    """
    
    # Write solution here (20 lines of code)
    pass

# %% [markdown]
# ## Test extract_reviews on any restaurant you have gathered in the previous part

# %%
#extract_reviews(you_url_here)
